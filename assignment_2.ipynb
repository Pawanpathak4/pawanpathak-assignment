# %% [markdown]
# ## question 1

# %%
import numpy as np

# %%
a=np.random.random(10).reshape(10,1)

# %%
a
# Out:
# array([[0.29799583],
#        [0.91108767],
#        [0.62611689],
#        [0.03846293],
#        [0.388061  ],
#        [0.89251553],
#        [0.69513949],
#        [0.1587832 ],
#        [0.24578929],
#        [0.75802759]])

# %%
np.mean(a)
# Out:
# 0.5011979421482644

# %% [markdown]
# ## question 2

# %%
b=np.random.random([20,1])

# %%
b
# Out:
# array([[0.67614451],
#        [0.42971841],
#        [0.39450658],
#        [0.45600968],
#        [0.37193065],
#        [0.34914475],
#        [0.96449648],
#        [0.52829573],
#        [0.60254939],
#        [0.87971026],
#        [0.94620153],
#        [0.13618603],
#        [0.84892737],
#        [0.77872082],
#        [0.64267115],
#        [0.87392473],
#        [0.95651302],
#        [0.0247836 ],
#        [0.37557068],
#        [0.71187352]])

# %%
np.var(b)
# Out:
# 0.07277031589200804

# %%
np.std(b)
# Out:
# 0.26975973734419306

# %% [markdown]
# ## question 3

# %%
c= np.random.random([10,20])

# %%
d= np.random.random([20,25])

# %%
e= np.dot(c,d)

# %%
e
# Out:
# array([[5.22894763, 5.29409825, 4.91481804, 4.71960208, 4.98764657,
#         5.88085223, 3.85843799, 5.10794882, 4.72280843, 3.90264429,
#         3.92912211, 4.93591625, 5.51956537, 5.0658619 , 4.05308245,
#         4.04311888, 5.2267389 , 4.90756748, 3.85076141, 5.58610625,
#         4.17719284, 4.74190004, 4.7814704 , 3.80587238, 4.83300118],
#        [4.86613118, 4.70331639, 4.31489639, 4.4532999 , 5.16339038,
#         5.79212219, 3.55117376, 4.59085621, 3.71490543, 3.27289874,
#         4.59730556, 5.24174393, 4.65463709, 3.64825604, 3.96246647,
#         4.32634894, 5.52360616, 3.74789489, 3.80100913, 5.50527014,
#         3.93572083, 4.22308727, 4.35652552, 4.07068785, 3.69426745],
#        [5.45935153, 5.54274945, 4.45841389, 4.9407945 , 5.75461795,
#         6.50249009, 4.69781231, 5.9928721 , 4.49681715, 4.45481736,
#         6.07704437, 5.33766633, 6.48381675, 4.99281209, 4.66706186,
#         5.26468006, 6.11533792, 4.58870404, 4.03235159, 6.16829447,
#         4.57677052, 4.5291792 , 5.27381259, 4.87056597, 5.52899776],
#        [5.44144179, 5.30503072, 4.94353994, 5.13071499, 5.76760781,
#         6.33499862, 3.9953851 , 5.10168429, 4.1391791 , 3.89085663,
#         5.31087366, 6.31091927, 5.64796495, 5.47944943, 4.748419  ,
#         4.88326236, 4.9824057 , 4.81624517, 4.94183011, 5.53896523,
#         3.79857402, 4.85198731, 5.16204568, 5.02689428, 4.57354646],
#        [4.50253811, 4.46556713, 3.54241321, 3.16674528, 3.93063258,
#         4.79205676, 3.17973053, 3.85277422, 3.60179325, 3.26584812,
#         3.68746656, 3.98482916, 4.94777496, 4.04551123, 3.74183033,
#         4.82911968, 4.35346515, 3.71709444, 3.52067208, 4.50886925,
#         3.42809498, 3.41501278, 4.02838828, 4.06642133, 3.5042635 ],
#        [5.1572929 , 4.15556283, 4.64657793, 4.72322275, 4.99021855,
#         5.64715232, 4.0344378 , 5.3043281 , 3.68380537, 4.0089762 ,
#         4.55373792, 4.43979837, 5.68451755, 4.34189597, 4.22807657,
#         4.98212361, 5.4581608 , 4.52195044, 4.15944053, 5.76190759,
#         3.44520671, 4.34790192, 5.04217651, 4.81931985, 4.35301302],
#        [4.85890798, 4.77449344, 3.99555763, 4.98069373, 4.55010949,
#         5.56111147, 3.29039496, 4.74542276, 3.71878973, 3.4419801 ,
#         4.65034538, 5.18375086, 5.89315351, 4.60362662, 4.414286  ,
#         4.17760833, 4.99831725, 4.41771692, 3.87952769, 5.22060354,
#         3.60639785, 3.69016607, 4.75972612, 4.19971163, 4.90889509],
#        [6.10748596, 5.94581905, 5.01038585, 5.37238149, 6.03389509,
#         6.8171904 , 4.3322995 , 6.06717222, 4.7571436 , 4.54359622,
#         5.97481149, 5.12560838, 6.52028076, 5.70790288, 4.15018324,
#         6.06652864, 6.0496794 , 5.16100294, 3.83361353, 5.71941685,
#         4.0732331 , 4.87556722, 5.98518264, 5.03410197, 5.54046333],
#        [4.96320847, 4.80621808, 3.73680216, 4.80051421, 4.33320273,
#         5.81373643, 4.62241811, 4.86571385, 3.57840158, 4.56273891,
#         4.74823875, 4.56111535, 6.35498994, 4.99544625, 4.79904955,
#         5.15821108, 4.93215136, 4.5508408 , 4.15880631, 5.9998995 ,
#         4.51183748, 4.1380634 , 4.665334  , 4.56105469, 4.64790145],
#        [6.2843851 , 6.1084761 , 4.73818893, 6.45365625, 5.4665632 ,
#         7.19585664, 5.05682674, 5.94238721, 5.18229927, 5.29574848,
#         5.59751765, 5.58005546, 7.77707042, 5.85765785, 5.86171953,
#         5.73068539, 6.57920201, 5.74131927, 4.56691704, 7.78077875,
#         5.65202989, 5.46110113, 6.07486257, 4.87390794, 6.22300478]])

# %%
e.shape
# Out:
# (10L, 25L)

# %%
np.sum(e)
# Out:
# 1212.5626204190235

# %% [markdown]
# ## question 4

# %%
f = np.arange(10).reshape(10,1)

# %%
def myfunc(x,axis):
    return 1/(1+np.exp(-x))

# %%
 np.apply_over_axes(myfunc,f,1)
# Out:
# array([[0.5       ],
#        [0.73105858],
#        [0.88079708],
#        [0.95257413],
#        [0.98201379],
#        [0.99330715],
#        [0.99752738],
#        [0.99908895],
#        [0.99966465],
#        [0.99987661]])
