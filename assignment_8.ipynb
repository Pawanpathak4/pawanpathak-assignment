# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn import preprocessing
# %matplotlib inline

# %%
 a = pd.read_csv("https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv")

# %%
a.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
a.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
a.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
b = a.iloc[:,2:21]

# %%
b.dtypes
# Out:
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
c = preprocessing.scale(b)

# %%
plt.boxplot(a["sqft_living"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xbb8e7dc5f8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xbb8e7dceb8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0xbb8e7dc4a8>],
#  'medians': [<matplotlib.lines.Line2D at 0xbb8e7ef748>],
#  'fliers': [<matplotlib.lines.Line2D at 0xbb8e7efb70>],
#  'means': []}

# %% [markdown]
# ## normalization

# %%
b = (b- b.min())/(b.max()-b.min())

# %%
b.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  0.019266  0.090909    0.12500     0.067170  0.003108     0.0         0.0
# 1  0.060721  0.090909    0.28125     0.172075  0.004072     0.4         0.0
# 2  0.013770  0.060606    0.12500     0.036226  0.005743     0.0         0.0
# 3  0.069377  0.121212    0.37500     0.126038  0.002714     0.0         0.0
# 4  0.057049  0.090909    0.25000     0.104906  0.004579     0.0         0.0
#
#    view  condition     grade  sqft_above  sqft_basement  yr_built  \
# 0   0.0        0.5  0.500000    0.097588       0.000000  0.478261
# 1   0.0        0.5  0.500000    0.206140       0.082988  0.443478
# 2   0.0        0.5  0.416667    0.052632       0.000000  0.286957
# 3   0.0        1.0  0.500000    0.083333       0.188797  0.565217
# 4   0.0        0.5  0.583333    0.152412       0.000000  0.756522
#
#    yr_renovated   zipcode       lat      long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# ## feature selection

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
var = VarianceThreshold(1)
arr = var.fit_transform(c)

# %%
arr
# Out:
# array([[-0.915427  , -0.08717263, -0.30575946, -0.21012839],
#        [ 0.93650577, -0.08717263, -0.30575946,  4.7466776 ],
#        [-0.915427  , -0.08717263, -0.30575946, -0.21012839],
#        ...,
#        [ 0.93650577, -0.08717263, -0.30575946, -0.21012839],
#        [ 0.93650577, -0.08717263, -0.30575946, -0.21012839],
#        [ 0.93650577, -0.08717263, -0.30575946, -0.21012839]])

# %% [markdown]
# ## heat map

# %%
plt.figure(figsize=(20,15)) 
sns.heatmap(a.corr(),annot=True)

# %% [markdown]
# ## Price depends mostly on the sqft_living so taking it

# %% [markdown]
# ## skewness

# %%
b = b["sqft_living"]

# %%
b.head()
# Out:
# 0    0.067170
# 1    0.172075
# 2    0.036226
# 3    0.126038
# 4    0.104906
# Name: sqft_living, dtype: float64

# %%
b.plot(kind = "kde")

# %%
b.mean() , b.std()
# Out:
# (0.1350867725486669, 0.06931629411674058)

# %%
c = np.power(b,1/2)

# %%
c =np.power(b,1/3)

# %%
b.mean(),b.std()
# Out:
# (0.1350867725486669, 0.06931629411674058)

# %%
c.mean(),c.std()
# Out:
# (0.4990794811873782, 0.08432832764102229)

# %%
b.plot(kind ="kde")

# %%
b = preprocessing.scale(b)

# %%
b
# Out:
# array([-0.97983502,  0.53363434, -1.42625404, ..., -1.15404732,
#        -0.52252773, -1.15404732])

# %%
b = pd.DataFrame(b)

# %%
b.plot(kind = "kde")

# %% [markdown]
# ## linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
target = a.iloc[:,2]

# %%
plt.scatter(x = b,y = target )

# %%
from sklearn.model_selection import train_test_split

# %%
b_train,b_test,target_train,target_test  = train_test_split(b,target,test_size = 0.2)

# %%
reg = LinearRegression()
reg.fit(b_train,target_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# array([261239.27073794])

# %%
reg.intercept_
# Out:
# 541143.74079654

# %%
arr    =  reg.predict(b_test)

# %%
arr
# Out:
# array([ 342061.22245575,  563927.80742321,  507038.93948284, ...,
#        1107216.49625378,  313616.78848557,  515572.26967389])

# %%
e = a.drop(['price','date'],axis=1)
f = a['price']

# %%
e_train, e_test, f_train, f_test = train_test_split(e,f, test_size=0.3)

# %%
reg.fit(e_train,f_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
f_pred = reg.predict(e_test)

# %%
f_pred
# Out:
# array([ 548351.71920874, 1630703.63900405,  404965.65722096, ...,
#        1023561.37974179,  853357.71674199,  331023.67266733])

# %%
g = pd.DataFrame({"actual":f_test,"predicted":f_pred})

# %%
g.insert(value = g.actual - g.predicted,column = "differences",loc = 2)

# %%
g
# Out:
#           actual     predicted   differences
# 4368    437000.0  5.483517e+05 -1.113517e+05
# 17647  1550000.0  1.630704e+06 -8.070364e+04
# 12708   475200.0  4.049657e+05  7.023434e+04
# 961     385000.0  2.414684e+05  1.435316e+05
# 4239    384400.0  5.471093e+05 -1.627093e+05
# 1527    713000.0  7.838542e+05 -7.085416e+04
# 13256  2546000.0  1.382738e+06  1.163262e+06
# 311     201000.0  2.360465e+05 -3.504650e+04
# 15356   350000.0  4.197598e+05 -6.975975e+04
# 16053   247500.0  2.041462e+05  4.335380e+04
# 13101   290000.0  2.196362e+05  7.036377e+04
# 20094   740000.0  8.755285e+05 -1.355285e+05
# 10134   546500.0  5.510435e+05 -4.543477e+03
# 6696    385000.0  5.909937e+05 -2.059937e+05
# 13924   870000.0  1.055992e+06 -1.859916e+05
# 5787    455000.0  4.235354e+05  3.146460e+04
# 395     330000.0  5.507013e+05 -2.207013e+05
# 13929   409950.0  4.618143e+05 -5.186433e+04
# 2504    475000.0  6.542409e+05 -1.792409e+05
# 11352  1164000.0  1.071578e+06  9.242202e+04
# ...
